# %% [markdown]
# ## *Import Libraries*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *Load Dataset*

# %%
tc=pd.read_csv('telecommunications_churn.csv')
tc
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0                128                1                   25     265.1
# 1                107                1                   26     161.6
# 2                137                0                    0     243.4
# 3                 84                0                    0     299.4
# 4                 75                0                    0     166.7
# ...              ...              ...                  ...       ...
# 3328             192                1                   36     156.2
# 3329              68                0                    0     231.1
# 3330              28                0                    0     180.8
# 3331             184                0                    0     213.8
# 3332              74                1                   25     234.4
#
#       evening_mins  night_mins  international_mins  customer_service_calls  \
# 0            197.4       244.7                10.0                       1
# 1            195.5       254.4                13.7                       1
# 2            121.2       162.6                12.2                       0
# 3             61.9       196.9                 6.6                       2
# 4            148.3       186.9                10.1                       3
# ...            ...         ...                 ...                     ...
# 3328         215.5       279.1                 9.9                       2
# 3329         153.4       191.3                 9.6                       3
# 3330         288.8       191.9                14.1                       2
# 3331         159.6       139.2                 5.0                       2
# 3332         265.9       241.4                13.7                       0
#
#       international_plan  day_calls  day_charge  evening_calls  \
# 0                      0        110       45.07             99
# 1                      0        123       27.47            103
# 2                      0        114       41.38            110
# 3                      1         71       50.90             88
# 4                      1        113       28.34            122
# ...                  ...        ...         ...            ...
# 3328                   0         77       26.55            126
# 3329                   0         57       39.29             55
# 3330                   0        109       30.74             58
# 3331                   1        105       36.35             84
# 3332                   0        113       39.85             82
#
#       evening_charge  night_calls  night_charge  international_calls  \
# 0              16.78           91         11.01                    3
# 1              16.62          103         11.45                    3
# 2              10.30          104          7.32                    5
# 3               5.26           89          8.86                    7
# 4              12.61          121          8.41                    3
# ...              ...          ...           ...                  ...
# 3328           18.32           83         12.56                    6
# 3329           13.04          123          8.61                    4
# 3330           24.55           91          8.64                    6
# 3331           13.57          137          6.26                   10
# 3332           22.60           77         10.86                    4
#
#       international_charge  total_charge  churn
# 0                     2.70         75.56      0
# 1                     3.70         59.24      0
# 2                     3.29         62.29      0
# 3                     1.78         66.80      0
# 4                     2.73         52.09      0
# ...                    ...           ...    ...
# 3328                  2.67         60.10      0
# 3329                  2.59         63.53      0
# 3330                  3.81         67.74      0
# 3331                  1.35         57.53      0
# 3332                  3.70         77.01      0
#
# [3333 rows x 19 columns]

# %% [markdown]
# ## ***EDA***

# %%
# Overview of the dataset

tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account_length          3333 non-null   int64
#  1   voice_mail_plan         3333 non-null   int64
#  2   voice_mail_messages     3333 non-null   int64
#  3   day_mins                3333 non-null   float64
#  4   evening_mins            3333 non-null   float64
#  5   night_mins              3333 non-null   float64
#  6   international_mins      3333 non-null   float64
#  7   customer_service_calls  3333 non-null   int64
#  8   international_plan      3333 non-null   int64
#  9   day_calls               3333 non-null   int64
#  10  day_charge              3333 non-null   float64
#  11  evening_calls           3333 non-null   int64
#  12  evening_charge          3333 non-null   float64
#  13  night_calls             3333 non-null   int64
#  14  night_charge            3333 non-null   float64
#  15  international_calls     3333 non-null   int64
#  16  international_charge    3333 non-null   float64
#  17  total_charge            3333 non-null   float64
#  18  churn                   3333 non-null   int64
# dtypes: float64(9), int64(10)
# memory usage: 494.9 KB

# %%
tc.columns
# Out:
# Index(['account_length', 'voice_mail_plan', 'voice_mail_messages', 'day_mins',
#        'evening_mins', 'night_mins', 'international_mins',
#        'customer_service_calls', 'international_plan', 'day_calls',
#        'day_charge', 'evening_calls', 'evening_charge', 'night_calls',
#        'night_charge', 'international_calls', 'international_charge',
#        'total_charge', 'churn'],
#       dtype='object')

# %%
#Display Summary

tc.describe()
# Out:
#        account_length  voice_mail_plan  voice_mail_messages     day_mins  \
# count     3333.000000      3333.000000          3333.000000  3333.000000
# mean       101.064806         0.276628             8.099010   179.775098
# std         39.822106         0.447398            13.688365    54.467389
# min          1.000000         0.000000             0.000000     0.000000
# 25%         74.000000         0.000000             0.000000   143.700000
# 50%        101.000000         0.000000             0.000000   179.400000
# 75%        127.000000         1.000000            20.000000   216.400000
# max        243.000000         1.000000            51.000000   350.800000
#
#        evening_mins   night_mins  international_mins  customer_service_calls  \
# count   3333.000000  3333.000000         3333.000000             3333.000000
# mean     200.980348   200.872037           10.237294                1.562856
# std       50.713844    50.573847            2.791840                1.315491
# min        0.000000    23.200000            0.000000                0.000000
# 25%      166.600000   167.000000            8.500000                1.000000
# 50%      201.400000   201.200000           10.300000                1.000000
# 75%      235.300000   235.300000           12.100000                2.000000
# max      363.700000   395.000000           20.000000                9.000000
#
#        international_plan    day_calls   day_charge  evening_calls  \
# count         3333.000000  3333.000000  3333.000000    3333.000000
# mean             0.096910   100.435644    30.562307     100.114311
# std              0.295879    20.069084     9.259435      19.922625
# min              0.000000     0.000000     0.000000       0.000000
# 25%              0.000000    87.000000    24.430000      87.000000
# 50%              0.000000   101.000000    30.500000     100.000000
# 75%              0.000000   114.000000    36.790000     114.000000
# max              1.000000   165.000000    59.640000     170.000000
#
#        evening_charge  night_calls  night_charge  international_calls  \
# count     3333.000000  3333.000000   3333.000000          3333.000000
# mean        17.083540   100.107711      9.039325             4.479448
# std          4.310668    19.568609      2.275873             2.461214
# min          0.000000    33.000000      1.040000             0.000000
# 25%         14.160000    87.000000      7.520000             3.000000
# 50%         17.120000   100.000000      9.050000             4.000000
# 75%         20.000000   113.000000     10.590000             6.000000
# max         30.910000   175.000000     17.770000            20.000000
#
#        international_charge  total_charge        churn
# count           3333.000000   3333.000000  3333.000000
# mean               2.764581     59.449754     0.144914
# std                0.753773     10.502261     0.352067
# min                0.000000     22.930000     0.000000
# 25%                2.300000     52.380000     0.000000
# 50%                2.780000     59.470000     0.000000
# 75%                3.270000     66.480000     0.000000
# max                5.400000     96.150000     1.000000

# %%
# Checking missingvalues

tc.isnull().sum()
# Out:
# account_length            0
# voice_mail_plan           0
# voice_mail_messages       0
# day_mins                  0
# evening_mins              0
# night_mins                0
# international_mins        0
# customer_service_calls    0
# international_plan        0
# day_calls                 0
# day_charge                0
# evening_calls             0
# evening_charge            0
# night_calls               0
# night_charge              0
# international_calls       0
# international_charge      0
# total_charge              0
# churn                     0
# dtype: int64

# %%
#checking datatypes

tc.dtypes
# Out:
# account_length              int64
# voice_mail_plan             int64
# voice_mail_messages         int64
# day_mins                  float64
# evening_mins              float64
# night_mins                float64
# international_mins        float64
# customer_service_calls      int64
# international_plan          int64
# day_calls                   int64
# day_charge                float64
# evening_calls               int64
# evening_charge            float64
# night_calls                 int64
# night_charge              float64
# international_calls         int64
# international_charge      float64
# total_charge              float64
# churn                       int64
# dtype: object

# %%
# Checking Duplicates

tc.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## ***Data Visualization***

# %%
numerical_cols = tc.select_dtypes(include=np.number).columns

# %%
#Histogram
selected_features=['account_length','day_mins','evening_mins','night_mins','international_mins','day_calls','day_charge','evening_calls','evening_charge',
                  'night_calls','night_charge','international_charge','total_charge']
for col in selected_features:
    plt.figure()
    sns.histplot(tc[col], kde=True)
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
# Bar Chart
sns.countplot(x='churn', data=tc)
plt.title('Churn Count Plot')
plt.xlabel('churn')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# correlation

tc.corr()
# Out:
#                         account_length  voice_mail_plan  voice_mail_messages  \
# account_length                1.000000         0.002918            -0.004628
# voice_mail_plan               0.002918         1.000000             0.956927
# voice_mail_messages          -0.004628         0.956927             1.000000
# day_mins                      0.006216        -0.001684             0.000778
# evening_mins                 -0.006757         0.021545             0.017562
# night_mins                   -0.008955         0.006079             0.007681
# international_mins            0.009514        -0.001318             0.002856
# customer_service_calls       -0.003796        -0.017824            -0.013263
# international_plan            0.024735         0.006006             0.008745
# day_calls                     0.038470        -0.011086            -0.009548
# day_charge                    0.006214        -0.001686             0.000776
# evening_calls                 0.019260        -0.006444            -0.005864
# evening_charge               -0.006745         0.021559             0.017578
# night_calls                  -0.013176         0.015553             0.007123
# night_charge                 -0.008960         0.006064             0.007663
# international_calls           0.020661         0.007618             0.013957
# international_charge          0.009546        -0.001276             0.002884
# total_charge                  0.001454         0.008585             0.009766
# churn                         0.016541        -0.102148            -0.089728
#
#                         day_mins  evening_mins  night_mins  \
# account_length          0.006216     -0.006757   -0.008955
# voice_mail_plan        -0.001684      0.021545    0.006079
# voice_mail_messages     0.000778      0.017562    0.007681
# day_mins                1.000000      0.007043    0.004323
# evening_mins            0.007043      1.000000   -0.012584
# night_mins              0.004323     -0.012584    1.000000
# international_mins     -0.010155     -0.011035   -0.015207
# customer_service_calls -0.013423     -0.012985   -0.009288
# international_plan      0.049396      0.019100   -0.028905
# day_calls               0.006750     -0.021451    0.022938
# day_charge              1.000000      0.007050    0.004324
# evening_calls           0.015769     -0.011430   -0.002093
# evening_charge          0.007029      1.000000   -0.012592
# night_calls             0.022972      0.007586    0.011204
# night_charge            0.004300     -0.012593    0.999999
# international_calls     0.008033      0.002541   -0.012353
# international_charge   -0.010092     -0.011067   -0.015180
# total_charge            0.884754      0.413143    0.214257
# churn                   0.205151      0.092796    0.035493
#
#                         international_mins  customer_service_calls  \
# account_length                    0.009514               -0.003796
# voice_mail_plan                  -0.001318               -0.017824
# voice_mail_messages               0.002856               -0.013263
# day_mins                         -0.010155               -0.013423
# evening_mins                     -0.011035               -0.012985
# night_mins                       -0.015207               -0.009288
# international_mins                1.000000               -0.009640
# customer_service_calls           -0.009640                1.000000
# international_plan                0.045871               -0.024522
# day_calls                         0.021565               -0.018942
# day_charge                       -0.010157               -0.013427
# evening_calls                     0.008703                0.002423
# evening_charge                   -0.011043               -0.012987
# night_calls                      -0.013605               -0.012802
# night_charge                     -0.015214               -0.009277
# international_calls               0.032304               -0.017561
# international_charge              0.999993               -0.009675
# total_charge                      0.054988               -0.019873
# churn                             0.068239                0.208750
#
#                         international_plan  day_calls  day_charge  \
# account_length                    0.024735   0.038470    0.006214
# voice_mail_plan                   0.006006  -0.011086   -0.001686
# voice_mail_messages               0.008745  -0.009548    0.000776
# day_mins                          0.049396   0.006750    1.000000
# evening_mins                      0.019100  -0.021451    0.007050
# night_mins                       -0.028905   0.022938    0.004324
# international_mins                0.045871   0.021565   -0.010157
# customer_service_calls           -0.024522  -0.018942   -0.013427
# international_plan                1.000000   0.003755    0.049398
# day_calls                         0.003755   1.000000    0.006753
# day_charge                        0.049398   0.006753    1.000000
# evening_calls                     0.006114   0.006462    0.015769
# evening_charge                    0.019106  -0.021449    0.007036
# night_calls                       0.012451  -0.019557    0.022972
# night_charge                     -0.028913   0.022927    0.004301
# international_calls               0.017366   0.004574    0.008032
# international_charge              0.045780   0.021666   -0.010094
# total_charge                      0.048415   0.003673    0.884757
# churn                             0.259852   0.018459    0.205151
#
#                         evening_calls  evening_charge  night_calls  \
# account_length               0.019260       -0.006745    -0.013176
# voice_mail_plan             -0.006444        0.021559     0.015553
# voice_mail_messages         -0.005864        0.017578     0.007123
# day_mins                     0.015769        0.007029     0.022972
# evening_mins                -0.011430        1.000000     0.007586
# night_mins                  -0.002093       -0.012592     0.011204
# international_mins           0.008703       -0.011043    -0.013605
# customer_service_calls       0.002423       -0.012987    -0.012802
# international_plan           0.006114        0.019106     0.012451
# day_calls                    0.006462       -0.021449    -0.019557
# day_charge                   0.015769        0.007036     0.022972
# evening_calls                1.000000       -0.011423     0.007710
# evening_charge              -0.011423        1.000000     0.007596
# night_calls                  0.007710        0.007596     1.000000
# night_charge                -0.002056       -0.012601     0.011188
# international_calls          0.017434        0.002541     0.000305
# international_charge         0.008674       -0.011074    -0.013630
# total_charge                 0.009392        0.413129     0.024818
# churn                        0.009233        0.092786     0.006141
#
#                         night_charge  international_calls  \
# account_length             -0.008960             0.020661
# voice_mail_plan             0.006064             0.007618
# voice_mail_messages         0.007663             0.013957
# day_mins                    0.004300             0.008033
# evening_mins               -0.012593             0.002541
# night_mins                  0.999999            -0.012353
# international_mins         -0.015214             0.032304
# customer_service_calls     -0.009277            -0.017561
# international_plan         -0.028913             0.017366
# day_calls                   0.022927             0.004574
# day_charge                  0.004301             0.008032
# evening_calls              -0.002056             0.017434
# evening_charge             -0.012601             0.002541
# night_calls                 0.011188             0.000305
# night_charge                1.000000            -0.012329
# international_calls        -0.012329             1.000000
# international_charge       -0.015186             0.032372
# total_charge                0.214233             0.007776
# churn                       0.035496            -0.052844
#
#                         international_charge  total_charge     churn
# account_length                      0.009546      0.001454  0.016541
# voice_mail_plan                    -0.001276      0.008585 -0.102148
# voice_mail_messages                 0.002884      0.009766 -0.089728
# day_mins                           -0.010092      0.884754  0.205151
# evening_mins                       -0.011067      0.413143  0.092796
# night_mins                         -0.015180      0.214257  0.035493
# international_mins                  0.999993      0.054988  0.068239
# customer_service_calls             -0.009675     -0.019873  0.208750
# international_plan                  0.045780      0.048415  0.259852
# day_calls                           0.021666      0.003673  0.018459
# day_charge                         -0.010094      0.884757  0.205151
# evening_calls                       0.008674      0.009392  0.009233
# evening_charge                     -0.011074      0.413129  0.092786
# night_calls                        -0.013630      0.024818  0.006141
# night_charge                       -0.015186      0.214233  0.035496
# international_calls                 0.032372      0.007776 -0.052844
# international_charge                1.000000      0.055036  0.068259
# total_charge                        0.055036      1.000000  0.231549
# churn                               0.068259      0.231549  1.000000

# %%
# calculates the number of outliers per column using IQR method
outliers_count = ((tc < (tc.quantile(0.25) - 1.5 * (tc.quantile(0.75) - tc.quantile(0.25)))) | (tc > (tc.quantile(0.75) + 1.5 * (tc.quantile(0.75) - tc.quantile(0.25))))).sum()
outliers_count
# Out:
# account_length             18
# voice_mail_plan             0
# voice_mail_messages         1
# day_mins                   25
# evening_mins               24
# night_mins                 30
# international_mins         46
# customer_service_calls    267
# international_plan        323
# day_calls                  23
# day_charge                 25
# evening_calls              20
# evening_charge             24
# night_calls                22
# night_charge               30
# international_calls        78
# international_charge       49
# total_charge               27
# churn                     483
# dtype: int64

# %%
# Box Plot

for col in numerical_cols:
  plt.figure()
  sns.boxplot(tc[col])
  plt.title(f"Boxplot of {col}")
  plt.show()

# %%
# Treating Outlier
def outlier_Detection(tc,columns):
    for col in columns:
        Q1=tc[col].quantile(0.25)
        Q3=tc[col].quantile(0.75)
        iqr=Q3-Q1
        lower=Q1-1.5*iqr
        upper=Q3+1.5*iqr
        tc[col]=np.where(tc[col]>upper,upper,np.where(tc[col]<lower,lower,tc[col]))
    return tc

# %%
outlier_Detection(tc,['account_length', 'voice_mail_messages', 'day_mins', 'evening_mins', 'night_mins', 'international_mins','customer_service_calls', 'day_calls','day_charge', 'evening_calls', 'evening_charge', 'night_calls', 'night_charge', 'international_calls', 'international_charge', 'total_charge'])
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0              128.0                1                 25.0     265.1
# 1              107.0                1                 26.0     161.6
# 2              137.0                0                  0.0     243.4
# 3               84.0                0                  0.0     299.4
# 4               75.0                0                  0.0     166.7
# ...              ...              ...                  ...       ...
# 3328           192.0                1                 36.0     156.2
# 3329            68.0                0                  0.0     231.1
# 3330            28.0                0                  0.0     180.8
# 3331           184.0                0                  0.0     213.8
# 3332            74.0                1                 25.0     234.4
#
#       evening_mins  night_mins  international_mins  customer_service_calls  \
# 0           197.40       244.7                10.0                     1.0
# 1           195.50       254.4                13.7                     1.0
# 2           121.20       162.6                12.2                     0.0
# 3            63.55       196.9                 6.6                     2.0
# 4           148.30       186.9                10.1                     3.0
# ...            ...         ...                 ...                     ...
# 3328        215.50       279.1                 9.9                     2.0
# 3329        153.40       191.3                 9.6                     3.0
# 3330        288.80       191.9                14.1                     2.0
# 3331        159.60       139.2                 5.0                     2.0
# 3332        265.90       241.4                13.7                     0.0
#
#       international_plan  day_calls  day_charge  evening_calls  \
# 0                      0      110.0       45.07           99.0
# 1                      0      123.0       27.47          103.0
# 2                      0      114.0       41.38          110.0
# 3                      1       71.0       50.90           88.0
# 4                      1      113.0       28.34          122.0
# ...                  ...        ...         ...            ...
# 3328                   0       77.0       26.55          126.0
# 3329                   0       57.0       39.29           55.0
# 3330                   0      109.0       30.74           58.0
# 3331                   1      105.0       36.35           84.0
# 3332                   0      113.0       39.85           82.0
#
#       evening_charge  night_calls  night_charge  international_calls  \
# 0              16.78         91.0         11.01                  3.0
# 1              16.62        103.0         11.45                  3.0
# 2              10.30        104.0          7.32                  5.0
# 3               5.40         89.0          8.86                  7.0
# 4              12.61        121.0          8.41                  3.0
# ...              ...          ...           ...                  ...
# 3328           18.32         83.0         12.56                  6.0
# 3329           13.04        123.0          8.61                  4.0
# 3330           24.55         91.0          8.64                  6.0
# 3331           13.57        137.0          6.26                 10.0
# 3332           22.60         77.0         10.86                  4.0
#
#       international_charge  total_charge  churn
# 0                     2.70         75.56      0
# 1                     3.70         59.24      0
# 2                     3.29         62.29      0
# 3                     1.78         66.80      0
# 4                     2.73         52.09      0
# ...                    ...           ...    ...
# 3328                  2.67         60.10      0
# 3329                  2.59         63.53      0
# 3330                  3.81         67.74      0
# 3331                  1.35         57.53      0
# 3332                  3.70         77.01      0
#
# [3333 rows x 19 columns]

# %%
# Box Plot after removing outliers

for col in numerical_cols:
  plt.figure()
  sns.boxplot(tc[col])
  plt.title(f"Boxplot of {col}")
  plt.show()

# %%
# calculates the number of outliers per column using IQR method
outliers_count = ((tc < (tc.quantile(0.25) - 1.5 * (tc.quantile(0.75) - tc.quantile(0.25)))) | (tc > (tc.quantile(0.75) + 1.5 * (tc.quantile(0.75) - tc.quantile(0.25))))).sum()
outliers_count
# Out:
# account_length              0
# voice_mail_plan             0
# voice_mail_messages         0
# day_mins                    0
# evening_mins                0
# night_mins                  0
# international_mins          0
# customer_service_calls      0
# international_plan        323
# day_calls                   0
# day_charge                  0
# evening_calls               0
# evening_charge              0
# night_calls                 0
# night_charge                0
# international_calls         0
# international_charge        0
# total_charge                0
# churn                     483
# dtype: int64

# %%
# Scatter plot
target= 'churn'
features= [col for col in tc.columns if col !=target]
for feature in features:
    sns.scatterplot(data=tc, x=feature, y=target)
    plt.title(f"{feature} vs {target}")
    plt.show()

# %%
# Heatmap

plt.figure(figsize=(18,10))
sns.heatmap(tc.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
# Pair plot

selected_features=['day_mins','evening_mins','night_mins','international_mins','churn']
sns.pairplot(tc[selected_features],hue='churn')
plt.show()

# %% [markdown]
# ## *Feature Engineering*

# %%
# Create the interaction feature

tc['avg_day_call_charge'] = tc['day_mins'] + tc['day_calls']+tc['day_charge']
tc['avg_evening_call_charge']=tc['evening_mins']+tc['evening_calls']+tc['evening_charge']
tc['avg_night_call_charge']=tc['night_mins']+tc['night_calls']+tc['night_charge']

# %%
tc.head()
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0           128.0                1                 25.0     265.1
# 1           107.0                1                 26.0     161.6
# 2           137.0                0                  0.0     243.4
# 3            84.0                0                  0.0     299.4
# 4            75.0                0                  0.0     166.7
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0        197.40       244.7                10.0                     1.0
# 1        195.50       254.4                13.7                     1.0
# 2        121.20       162.6                12.2                     0.0
# 3         63.55       196.9                 6.6                     2.0
# 4        148.30       186.9                10.1                     3.0
#
#    international_plan  day_calls  ...  evening_charge  night_calls  \
# 0                   0      110.0  ...           16.78         91.0
# 1                   0      123.0  ...           16.62        103.0
# 2                   0      114.0  ...           10.30        104.0
# 3                   1       71.0  ...            5.40         89.0
# 4                   1      113.0  ...           12.61        121.0
#
#    night_charge  international_calls  international_charge  total_charge  \
# 0         11.01                  3.0                  2.70         75.56
# 1         11.45                  3.0                  3.70         59.24
# 2          7.32                  5.0                  3.29         62.29
# 3          8.86                  7.0                  1.78         66.80
# 4          8.41                  3.0                  2.73         52.09
#
#    churn  avg_day_call_charge  avg_evening_call_charge  avg_night_call_charge
# 0      0               420.17                   313.18                 346.71
# 1      0               312.07                   315.12                 368.85
# 2      0               398.78                   241.50                 273.92
# 3      0               421.30                   156.95                 294.76
# 4      0               308.04                   282.91                 316.31
#
# [5 rows x 22 columns]

# %%
# Normalization

from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
ts = pd.DataFrame(scalar.fit_transform(tc.drop(columns=['churn'])),columns=tc.columns[:-1])
ts['churn']=tc['churn']

# %%
ts
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0           0.618005              1.0                 0.50  0.792469
# 1           0.515815              1.0                 0.52  0.436554
# 2           0.661800              0.0                 0.00  0.717847
# 3           0.403893              0.0                 0.00  0.910420
# 4           0.360097              0.0                 0.00  0.454092
# ...              ...              ...                  ...       ...
# 3328        0.929440              1.0                 0.72  0.417985
# 3329        0.326034              0.0                 0.00  0.675550
# 3330        0.131387              0.0                 0.00  0.502579
# 3331        0.890511              0.0                 0.00  0.616059
# 3332        0.355231              1.0                 0.50  0.686898
#
#       evening_mins  night_mins  international_mins  customer_service_calls  \
# 0         0.487082    0.659407            0.479167                0.285714
# 1         0.480167    0.694912            0.736111                0.285714
# 2         0.209789    0.358895            0.631944                0.000000
# 3         0.000000    0.484444            0.243056                0.571429
# 4         0.308406    0.447840            0.486111                0.857143
# ...            ...         ...                 ...                     ...
# 3328      0.552948    0.785322            0.472222                0.571429
# 3329      0.326965    0.463946            0.451389                0.857143
# 3330      0.819687    0.466142            0.763889                0.571429
# 3331      0.349527    0.273243            0.131944                0.571429
# 3332      0.736354    0.647328            0.736111                0.000000
#
#       international_plan  day_calls  ...  evening_calls  evening_charge  \
# 0                    0.0   0.587963  ...       0.486111        0.487158
# 1                    0.0   0.708333  ...       0.523148        0.480308
# 2                    0.0   0.625000  ...       0.587963        0.209760
# 3                    1.0   0.226852  ...       0.384259        0.000000
# 4                    1.0   0.615741  ...       0.699074        0.308647
# ...                  ...        ...  ...            ...             ...
# 3328                 0.0   0.282407  ...       0.736111        0.553082
# 3329                 0.0   0.097222  ...       0.078704        0.327055
# 3330                 0.0   0.578704  ...       0.106481        0.819777
# 3331                 1.0   0.541667  ...       0.347222        0.349743
# 3332                 0.0   0.615741  ...       0.328704        0.736301
#
#       night_calls  night_charge  international_calls  international_charge  \
# 0        0.413462      0.659202             0.285714              0.478093
# 1        0.528846      0.695033             0.285714              0.735825
# 2        0.538462      0.358713             0.476190              0.630155
# 3        0.394231      0.484121             0.666667              0.240979
# 4        0.701923      0.447476             0.285714              0.485825
# ...           ...           ...                  ...                   ...
# 3328     0.336538      0.785423             0.571429              0.470361
# 3329     0.721154      0.463762             0.380952              0.449742
# 3330     0.413462      0.466205             0.571429              0.764175
# 3331     0.855769      0.272394             0.952381              0.130155
# 3332     0.278846      0.646987             0.380952              0.735825
#
#       total_charge  churn  avg_day_call_charge  avg_evening_call_charge
# 0         0.785993      0             0.494152                 0.588609
# 1         0.496631      0             0.499000                 0.648048
# 2         0.550709      0             0.315015                 0.393189
# 3         0.630674      0             0.103714                 0.449138
# 4         0.369858      0             0.418504                 0.506994
# ...            ...    ...                  ...                      ...
# 3328      0.511879      0             0.610711                 0.663646
# 3329      0.572695      0             0.264882                 0.524713
# 3330      0.647340      0             0.639526                 0.440493
# 3331      0.466312      0             0.354176                 0.416116
# 3332      0.811702      0             0.637402                 0.541761
#
# [3333 rows x 21 columns]

# %% [markdown]
# ## *Import Libraries*

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.cluster import KMeans

# %%
x=ts.drop(['churn'],axis=1)
y=ts['churn']

# %%
x.head()
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0        0.618005              1.0                 0.50  0.792469
# 1        0.515815              1.0                 0.52  0.436554
# 2        0.661800              0.0                 0.00  0.717847
# 3        0.403893              0.0                 0.00  0.910420
# 4        0.360097              0.0                 0.00  0.454092
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0      0.487082    0.659407            0.479167                0.285714
# 1      0.480167    0.694912            0.736111                0.285714
# 2      0.209789    0.358895            0.631944                0.000000
# 3      0.000000    0.484444            0.243056                0.571429
# 4      0.308406    0.447840            0.486111                0.857143
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# 0                 0.0   0.587963    0.792476       0.486111        0.487158
# 1                 0.0   0.708333    0.436489       0.523148        0.480308
# 2                 0.0   0.625000    0.717840       0.587963        0.209760
# 3                 1.0   0.226852    0.910396       0.384259        0.000000
# 4                 1.0   0.615741    0.454086       0.699074        0.308647
#
#    night_calls  night_charge  international_calls  international_charge  \
# 0     0.413462      0.659202             0.285714              0.478093
# 1     0.528846      0.695033             0.285714              0.735825
# 2     0.538462      0.358713             0.476190              0.630155
# 3     0.394231      0.484121             0.666667              0.240979
# 4     0.701923      0.447476             0.285714              0.485825
#
#    total_charge  avg_day_call_charge  avg_evening_call_charge
# 0      0.785993             0.494152                 0.588609
# 1      0.496631             0.499000                 0.648048
# 2      0.550709             0.315015                 0.393189
# 3      0.630674             0.103714                 0.449138
# 4      0.369858             0.418504                 0.506994

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: churn, dtype: int64

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.2 , random_state = 1)

# %% [markdown]
# ## *Model Building*

# %%
# Automatic Model Building

def prediction(model):
    model.fit(xtrain, ytrain)
    y_pred = model.predict(xtest)
    
    train_acc = model.score(xtrain, ytrain)
    test_acc = model.score(xtest, ytest)
    print(f"Train Accuracy:{model.score(xtrain,ytrain)}")
    print(f"Test Accuracy:{model.score(xtrain,ytrain)}")
    print(classification_report(ytest,y_pred))

    return test_acc

# %%
# Using Logistic Regression

prediction(LogisticRegression())
# Out:
# Train Accuracy:0.8603603603603603
# Test Accuracy:0.8603603603603603
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2285
#            1       0.59      0.16      0.25       382
#
#     accuracy                           0.86      2667
#    macro avg       0.73      0.57      0.59      2667
# weighted avg       0.83      0.86      0.83      2667
# 0.863517060367454

# %%
# Using Support Vector Machine

prediction(SVC())
# Out:
# Train Accuracy:0.9234234234234234
# Test Accuracy:0.9234234234234234
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      2285
#            1       0.84      0.35      0.49       382
#
#     accuracy                           0.90      2667
#    macro avg       0.87      0.67      0.72      2667
# weighted avg       0.89      0.90      0.88      2667
# 0.8965129358830146

# %%
# Using Decision Tree Classifier

prediction(DecisionTreeClassifier())
# Out:
# Train Accuracy:1.0
# Test Accuracy:1.0
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2285
#            1       0.84      0.83      0.84       382
#
#     accuracy                           0.95      2667
#    macro avg       0.91      0.90      0.90      2667
# weighted avg       0.95      0.95      0.95      2667
# 0.9535058117735283

# %%
# Using Random Forest Classifier

prediction(RandomForestClassifier())
# Out:
# Train Accuracy:1.0
# Test Accuracy:1.0
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      2285
#            1       0.95      0.72      0.82       382
#
#     accuracy                           0.95      2667
#    macro avg       0.95      0.86      0.90      2667
# weighted avg       0.95      0.95      0.95      2667
# 0.9542557180352456

# %%
# Using KNN

prediction( KNeighborsClassifier())
# Out:
# Train Accuracy:0.918918918918919
# Test Accuracy:0.918918918918919
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94      2285
#            1       0.74      0.30      0.43       382
#
#     accuracy                           0.88      2667
#    macro avg       0.82      0.64      0.68      2667
# weighted avg       0.87      0.88      0.86      2667
# 0.884514435695538

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "KNeighborsClassifier": KNeighborsClassifier()
}

# Variable to store the best model and its accuracy
best_model = None
best_accuracy = 0
model_accuracies = {}

# Evaluate each model
for name, model in models.items():
    print(f"Evaluating {name}...")
    acc = prediction(model)  # Assuming prediction function gives accuracy for the model
    model_accuracies[name] = acc
    
    if acc > best_accuracy:
        best_accuracy = acc
        best_model = model  # Store the actual model, not the name
print(f"Best Model: {type(best_model).__name__}")
print(f"with accuracy: {best_accuracy}")
# Out:
# Evaluating Logistic Regression...
# Train Accuracy:0.8603603603603603
# Test Accuracy:0.8603603603603603
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2285
#            1       0.59      0.16      0.25       382
#
#     accuracy                           0.86      2667
#    macro avg       0.73      0.57      0.59      2667
# weighted avg       0.83      0.86      0.83      2667
#
# Evaluating Random Forest...
# Train Accuracy:1.0
# Test Accuracy:1.0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      2285
#            1       0.99      0.70      0.82       382
#
#     accuracy                           0.96      2667
#    macro avg       0.97      0.85      0.90      2667
# weighted avg       0.96      0.96      0.95      2667
#
# Evaluating SVM...
# Train Accuracy:0.9234234234234234
# Test Accuracy:0.9234234234234234
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      2285
#            1       0.84      0.35      0.49       382
#
#     accuracy                           0.90      2667
#    macro avg       0.87      0.67      0.72      2667
# weighted avg       0.89      0.90      0.88      2667
#
# Evaluating Decision Tree Classifier...
# Train Accuracy:1.0
# Test Accuracy:1.0
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2285
#            1       0.82      0.84      0.83       382
#
#     accuracy                           0.95      2667
#    macro avg       0.90      0.90      0.90      2667
# weighted avg       0.95      0.95      0.95      2667
#
# Evaluating KNeighborsClassifier...
# Train Accuracy:0.918918918918919
# Test Accuracy:0.918918918918919
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94      2285
#            1       0.74      0.30      0.43       382
#
#     accuracy                           0.88      2667
#    macro avg       0.82      0.64      0.68      2667
# weighted avg       0.87      0.88      0.86      2667
#
# Best Model: RandomForestClassifier
# with accuracy: 0.9561304836895388

# %% [markdown]
# # *Boost the accuracy*

# %%
# Cross-validation for LightGBM

lgbm_model = lgb.LGBMClassifier()

# %%
lgbm_cv_scores = cross_val_score(lgbm_model, x, y, cv=5, scoring='accuracy')
# Out:
# [LightGBM] [Info] Number of positive: 386, number of negative: 2280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3103
# [LightGBM] [Info] Number of data points in the train set: 2666, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.144786 -> initscore=-1.776093
# [LightGBM] [Info] Start training from score -1.776093
# [LightGBM] [Info] Number of positive: 386, number of negative: 2280
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000900 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3103
# [LightGBM] [Info] Number of data points in the train set: 2666, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.144786 -> initscore=-1.776093
# [LightGBM] [Info] Start training from score -1.776093
# [LightGBM] [Info] Number of positive: 386, number of negative: 2280
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000855 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3106
# [LightGBM] [Info] Number of data points in the train set: 2666, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.144786 -> initscore=-1.776093
# [LightGBM] [Info] Start training from score -1.776093
# [LightGBM] [Info] Number of positive: 387, number of negative: 2280
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000845 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3098
# [LightGBM] [Info] Number of data points in the train set: 2667, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.145107 -> initscore=-1.773506
# [LightGBM] [Info] Start training from score -1.773506
# [LightGBM] [Info] Number of positive: 387, number of negative: 2280
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000827 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3098
# [LightGBM] [Info] Number of data points in the train set: 2667, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.145107 -> initscore=-1.773506
# [LightGBM] [Info] Start training from score -1.773506

# %%
# Print the mean cross-validation score
print(f"LightGBM Mean Cross-Validation Accuracy: {lgbm_cv_scores.mean():.4f}")
# Out:
# LightGBM Mean Cross-Validation Accuracy: 0.9784

# %% [markdown]
# # *Deployment*

# %%
import joblib

joblib.dump(best_model, "Tele-communication_model.pkl")
print ("Model saved as 'Tele-communication_model.pkl'.")
# Out:
# Model saved as 'Tele-communication_model.pkl'.

# %%
import nbformat
from nbconvert import PythonExporter

# %%
#Load the notebook

notebook_filename = "Tele-communication.ipynb"
with open (notebook_filename, 'r', encoding='utf-8') as notebook_file:
    notebook_content = nbformat.read( notebook_file, as_version=4 )

# %%
# Convert to Python script

python_exporter = PythonExporter()
python_code, _ = python_exporter.from_notebook_node(notebook_content)

# %%
# Saving to a '.py' file

python_filename = notebook_filename.replace('.ipynb','.py')
with open(python_filename, 'w', encoding='utf-8') as python_file:
    python_file.write(python_code)

print(f" Notebook converted to {python_filename}")
# Out:
#  Notebook converted to Tele-communication.py

# %%
import streamlit as st
import numpy as np
import pandas as pd
import joblib

# %%
#Load the trained model

Model_File = 'Tele-communication_model.pkl' # Replacing it with model file name
model = joblib.load(Model_File)

# %%
# Streamlit App Title
st.title('Telecommunication Model Churn Prediction')
st.write("Enter the Values to predict the churn")
# Out:
# 2025-02-11 19:19:28.241
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Admin\anaconda\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# Input fields for churn 

account_length = st.number_input("Account Length", min_value=0)
voice_mail_plan = st.selectbox("Voice Mail Plan", options=[0, 1])  # 0 = No, 1 = Yes
voice_mail_messages = st.number_input("Voice Mail Messages", min_value=0)
day_mins = st.number_input("Day Minutes", min_value=0.0)
evening_mins = st.number_input("Evening Minutes", min_value=0.0)
night_mins = st.number_input("Night Minutes", min_value=0.0)
international_mins = st.number_input("International Minutes", min_value=0)
customer_service_calls = st.number_input("Customer Service Calls", min_value=0)
international_plan = st.selectbox("International Plan", options=[0, 1])  # 0 = No, 1 = Yes
day_calls = st.number_input("Day Calls", min_value=0)
day_charge = st.number_input("Day Charge", min_value=0.0)
evening_calls = st.number_input("Evening Calls", min_value=0)
evening_charge = st.number_input("Evening Charge", min_value=0.0)
night_calls = st.number_input("Night Calls", min_value=0)
night_charge = st.number_input("Night Charge", min_value=0.0)
international_calls = st.number_input("International Calls", min_value=0)
international_charge = st.number_input("International Charge", min_value=0.0)
total_charge = st.number_input("Total Charge", min_value=0.0)
# Out:
# 2025-02-11 19:19:28.267 Session state does not function when running a script without `streamlit run`

# %%
if st.button(" Predict "):
    # Creating input array

    missing_feature_1 = 0  # Replace with actual missing feature
    missing_feature_2 = 0  # Replace with actual missing feature
    
    input_features = np.array([account_length, voice_mail_plan, voice_mail_messages, day_mins, evening_mins, night_mins,
                               international_mins, customer_service_calls, international_plan, day_calls, day_charge, evening_calls,
                               evening_charge, night_calls, night_charge, international_calls, international_charge, total_charge,
                              missing_feature_1,missing_feature_2])
    
   # Reshape the input features to be a 2D array (1 sample with 19 features)
    input_features = input_features.reshape(1, -1)
    
    # Making a Prediction
    predicted_churn = model.predict(input_features)[0]

    # Displaying the result
    st.success(f"The Predicted Churn is : {predicted_churn:.2f}")
